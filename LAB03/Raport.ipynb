# %% [markdown]
# # LAB 03: Përdorimi i Markdown dhe LaTeX në JupyterLab
# *Kursi:* Hyrje Laborator (Fizike dhe Shkenca Kompjuterike)
#
# *Studenti:* Donaldo Shtjefni
#
# *Data:* 27.03.2026
#
# Në këtë laborator, do të demonstrojmë aftësitë e formatimit të tekstit, listave dhe paraqitjes së formulave komplekse matematike.

# %% [markdown]
# ## 1. Qëllimi i Laboratorit
# Ky laborator synon të pajisë studentin me aftësitë e nevojshme për hartimin e raporteve shkencore dhe teknike. Objektivat kryesore janë:
#
# 1. * Standardizimi i Dokumentimit:* Mësimi i rregullave të formatimit të tekstit që përdoren universalisht në platforma si GitHub dhe Jupyter.
# 2. * Prezantimi i të Dhënave:* Krijimi i tabelave dhe listave të strukturuara për të shfaqur rezultatet e eksperimenteve.
# 3. * Saktësia Matematike:* Përdorimi i sintaksës LaTeX për të shkruar formula që nuk mund të shkruhen me tekst të thjeshtë.
# 4. * Integrimi i Kodit:* Paraqitja e blloqeve të kodit (Python) në mënyrë që të jenë të lexueshëm dhe të ndarë nga pjesa narrative e raportit.

# %% [markdown]
# ## 2. Ushtrime Praktike
#
# ### Ushtrimi I: Formatimi i Tekstit dhe Tabelat
# Në këtë ushtrim paraqiten komandat kryesore për menaxhimin e tekstit:
#
# | Veprimi | Sintaksa | Rezultati |
# | :--- | :--- | :--- |
# | *Bolding* | **Fjala** | **E trashë** |
# | Italics | *Fjala* | E pjerrët |
# | Listë me pika | * Elementi | • Elementi |
# | Kod i shkurtër | `` var = 5 `` | var = 5 |

# %% [markdown]
# ### Ushtrimi II: Ekuacionet me LaTeX
# Më poshtë janë shkruar tri formula të rëndësishme duke përdorur simbolet $:
#
# 1. *Ligji i Gravitacionit:*
#    $$F = G \frac{m_1 m_2}{r^2}$$
#
# 2. *Energjia Kinetike:*
#    $$E_k = \frac{1}{2} m v^2$$
#
# 3. *Shuma Matematike (Sigma):*
#    $$\sum_{i=1}^{n} i = \frac{n(n+1)}{2}$$

# %% [markdown]
# ### Ushtrimi III: Blloku i Kodit
# Paraqitja e një funksioni të thjeshtë në Python që llogarit sipërfaqen e rrethit:
#
# ```python
# import math
#
# def llogarit_siperfaqen(rrezja):
#     return math.pi * (rrezja ** 2)
#
# print(f"Siperfaqja: {llogarit_siperfaqen(5):.2f}")

# %% [markdown]
# ### 3. Formulat Statistikore (LaTeX)
#
# Për të gjetur *Devijimin Standart* të matjeve, përdorim formulën:
#
# $$\sigma = \sqrt{\frac{1}{N-1} \sum_{i=1}^{N} (x_i - \bar{x})^2}$$
#
# Ku:
# * $\sigma$ është devijimi standart.
# * $N$ është numri i matjeve.
# * $\bar{x}$ është vlera mesatare ($\frac{1}{N} \sum x_i$).

# %% [markdown]
# ## 5. Konkluzione dhe Përfundime
#
# Pas përfundimit të këtij laboratori, mund të nxirren këto përfundime kryesore mbi dokumentimin teknik:
#
# * * Strukturimi i Qartë:* Përdorimi i hierarkisë së titujve (#, ##, ###) ndihmon në navigimin e shpejtë të raportit dhe e bën atë më të lexueshëm për profesorin dhe kolegët.
# * * Prezantimi Profesional:* Tabelat në Markdown janë një mjet i fuqishëm për të paraqitur të dhënat eksperimentale pa pasur nevojë për softuerë të jashtëm si Excel.
# * * Saktësia Shkencore:* Integrimi i *LaTeX* është i pazëvendësueshëm për shkrimin e formulave fizike dhe matematike, duke siguruar që simbolet si $\sum$, $\sqrt{x}$ dhe thyesat të duken saktësisht si në tekstet shkollore.
# * * Efikasiteti:* Jupyter Notebook na lejon të kemi kodin (Python), shpjegimin (Markdown) dhe rezultatet (Output) në një vend të vetëm, gjë që rrit transparencën e punës sonë

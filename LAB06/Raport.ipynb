# %% [markdown]
# # LAB06: Instrumentet Matëse në Fizikë
#
#
# **Lënda:** Hyrje Laborator (Fizike dhe Shkenca Kompjuterike)
#
# **Studenti:** Donaldo Shtjefni
#
# **Data:** 15 Prill 2026
#
# ---
#
# ## 1. Qëllimi i Punës Laboratorike
#
# Qëllimi i këtij laboratori është njohja praktike me instrumentet kryesore që përdoren për matjen e gjatësisë dhe masës.
# Përmes kësaj detyre, synojmë:
# * Të kuptojmë parimin e punës së secilit instrument.
# * Të përcaktojmë vlerën më të vogël të shkallës (VMS) për secilin mjet.
# * Të kryejmë matje direkte mbi objekte të ndryshme dhe të dokumentojmë saktësinë e tyre.

# %% [markdown]
# ## 2. Instrumentet e përdorura dhe funksioni i tyre
#
# Gjatë këtij laboratori kemi përdorur pajisjet e mëposhtme:
#
# 1. **Vizorja Milimetrike:**
#    * *Përdorimi:* Shërben për matjen e gjatësive të thjeshta dhe të drejta ku nuk kërkohet saktësi e lartë.
#    * *Saktësia:* Zakonisht $1 \text{ mm}$.
#
# 2. **Kalibri:**
#    * *Përdorimi:* Instrument i gjithanshëm që shërben për matjen e diametrave të jashtëm, diametrave të brendshëm (p.sh. gryka e një epruvete) dhe thellësisë.
#    * *Saktësia:* $0.1 \text{ mm}$ ose $0.05 \text{ mm}$.
#
# 3. **Mikrometri:**
#    * *Përdorimi:* Shërben për matjen e dimensioneve shumë të vogla si trashësia e një flete, diametri i një teli ose i një sferë të vogël metalike.
#    * *Saktësia:* Shumë e lartë, deri në $0.01 \text{ mm}$.
#
# 4. **Sferometri:**
#    * *Përdorimi:* Përdoret specifikisht për të matur rrezen e kurbaturës së sipërfaqeve sferike ose trashësinë e objekteve të rrafshëta e të holla.
#
# 5. **Peshorja Elektronike:**
#    * *Përdorimi:* Shërben për përcaktimin e masës së objekteve me një lexim të shpejtë digjital.
#    * *Saktësia:* Varion nga $0.1 \text{ g}$ deri në $0.01 \text{ g}$ (sipas modelit).
#
# 6. **Peshorja Manuale:**
#    * *Përdorimi:* Përcaktimi i masës përmes krahasimit të peshave etalon në dy krahët e peshores deri në arritjen e ekuilibrit.

# %% [markdown]
# ## # 3. Matjet Eksperimentale
#
# ### A. Matje me Vizore
# *Objekti:* Kuti Seti Matematikor (Metalike)
# * *Gjatësia:* $18.2 \text{ cm}$
# * *Gjerësia:* $7.5 \text{ cm}$
# * *Lartësia:* $2.0 \text{ cm}$
#
# ### B. Matje me Kalibër
# *Objekti:* Bateria e Laptopit (ose Powerbank)
# * *Trashësia:* $14.15 \text{ mm}$
# * *Gjerësia:* $62.30 \text{ mm}$
# * *Gjatësia:* $110.12 \text{ mm}$
# *
# ### C. Matja e Masës (Peshore Manuale)
# *Objekti:* Telefon Google Pixel 7
# * *Masa ($m$):* $197 \text{ g}$$
#
# ### D. Matja e Masës (Peshore Elektronike)
# *Objekti:* Çelësat e makinës me mbajtëse
# * *Masa ($m$):* $54 \text{ g}$
#
# ### E. Matja e një Globi të vogël(Sferometer)
# *Objekti:* Glob dekorativ (Sferë)
# * *Instrumenti:* Kalibër (për diametrin e jashtëm)
# * *Diametri i matur ($D$):* $120.4 \text{ mm}$ (ose $12.04 \text{ cm}$)
# * *Instrumenti alternative:* Sferometër (për të matur kurbaturën e sipërfaqes)
# * *Lartësia e matur ($h$):* $4.52 \text{ mm}$
#
# ## F. Matja me Mikrometër
# *Objekti:* Tel çeliku i hollë (ose fije plastike)
# * *Diametri ($d$):* $0.42 \text{ mm}$

# %% [markdown]
# ## 4. Tabela Përmbledhëse e të Dhënave (Varianti C)
#
# | Objekti | Instrumenti | Madhësia Fizike | Vlera e Matur | Pasiguria (Saktësia) |
# | :--- | :--- | :--- | :--- | :--- |
# | *Kuti Metalike* | Vizore | Përmasat ($l, b, h$) | $18.2 \times 7.5 \times 2.0 \text{ cm}$ | $\pm 0.1 \text{ cm}$ |
# | *Powerbank* | Kalibër | Përmasat ($l, b, t$) | $110.12 \times 62.3 \times 14.15 \text{ mm}$ | $\pm 0.02 \text{ mm}$ |
# | *Google Pixel 7* | Peshore Manuale | Masa ($m$) | $197 \text{ g}$ | $\pm 0.5 \text{ g}$ |
# | *Çelësa makine* | Peshore Elektronike | Masa ($m$) | $54 \text{ g}$ | $\pm 0.1 \text{ g}$ |
# | *Glob Dekorativ* | Kalibër / Sferometër | Diametri / Kurbatura | $120.4 \text{ mm} / 4.52 \text{ mm}$ | $\pm 0.1 / \pm 0.01 \text{ mm}$ |
# | *Tel Çeliku* | Mikrometër | Diametri ($d$) | $0.42 \text{ mm}$ | $\pm 0.01 \text{ mm}$ |

# %% [markdown]
# ## 5. Analiza e Rezultateve dhe Përfundime
#
# Si përfundim i punës laboratorike LAB06, u arritën rezultatet e mëposhtme:
#
# * *Saktësia Instrumentale:* U konfirmua se përdorimi i instrumenteve me ndjeshmëri të lartë, si *mikrometri* dhe *kalibri*, është i domosdoshëm për pjesë inxhinierike dhe laboratorike. Për shembull, diametri i telit prej $0.42 \text{ mm}$ nuk mund të përcaktohej me saktësi me asnjë mjet tjetër përveç mikrometrit.
# * *Vlerësimi i Gabimeve:* Matjet treguan se pasiguria eksperimentale ($\pm \Delta x$) është e lidhur drejtpërdrejt me vlerën më të vogël të shkallës së instrumentit. Gjatë procesit, u tregua kujdes i veçantë për të shmangur gabimet sistematike duke kalibruar peshoren elektronike para përdorimit.
# * *Kurbatura dhe Sipërfaqja:* Përdorimi i *sferometrit* na mundësoi llogaritjen e kurbaturës së sipërfaqeve të lakuara, duke vërtetuar se gjeometritë sferike kërkojnë instrumente specifike që bazohen në parimin e vidës mikrometrike.
# * *Konkluzion Final:* Ky laborator na ndihmoi të kuptojmë se saktësia e një matjeje nuk varet vetëm nga mjeti, por edhe nga teknika e përdorur nga eksperimentuesi, duke vënë theksin te leximi korrekt i noniusit dhe ekuilibrimi i peshores manuale.
